# %% [markdown]
# ## Test GPU / CPU Devices available

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 3767347249636915
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11320098816
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 8160927961055187471
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
#  xla_global_id: 416903419]

# %% [markdown]
# ### IPYTHON Server monitor inspired by htop

# %%
# !pip install --user nbtop

# %%
# !pip install tensorflow-gpu

# %%
# !pip show tensorflow-gpu

# %% [markdown]
# ## Import code from Drive Folders

# %%
from google.colab import drive
drive.mount("/content/drive")
# drive.mount('/content/drive')
! ls
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-6-99c01fabf671> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount("/content/drive")
#       3 # drive.mount('/content/drive')
#       4 get_ipython().system(' ls')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms)
#     107       force_remount=force_remount,
#     108       timeout_ms=timeout_ms,
# --> 109       ephemeral=True)
#     110
#     111
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral)
#     122   if ephemeral:
#     123     _message.blocking_request(
# --> 124         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     125
#     126   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %%
# %cd /content/drive/My Drive/Colab\ Notebooks/data/DRIVE
# !ls

# %%
# %cd /content/drive/My Drive/Colab\ Notebooks/Retinal_Image_Analysis\ Project/code_venv1

# %%
# !ls

# %% [markdown]
# ## Read from Github Private Repo
# import os
# from getpass import getpass
# import urllib
#
# user = input('User name: ')
# password = getpass('Password: ')
# password = urllib.parse.quote(password) # your password is converted into url format
# repo_name = input('Repo name: ')
#
# cmd_string = 'git clone https://{0}:{1}@github.com/{0}/{2}.git'.format(user, password, repo_name)
#
# os.system(cmd_string)
# cmd_string, password = "", "" # removing the password from the variable

# %% [markdown]
# ## Disk / CPU / GPU info

# %%
# !df -h

# %%
# !cat /proc/cpuinfo

# %%
# !cat /proc/meminfo

# %%
# TCMALLOC_LARGE_ALLOC_REPORT_THRESHOLD=21329330176

# %% [markdown]
# # Code Core

# %%
# !python3 preprocess.py

# %%
# !pip install albumentations==0.4.6

# %%
# !pip install scikit-learn==0.19.0

# %%
# import sys
# nb_path = "/content/drive/My Drive/Colab Notebooks"
# if nb_path not in sys.path:
#   sys.path.insert(5, nb_path)

#Call pip install on 1st time only
# !pip install tensorflow==1.14 #--target="{nb_path}"

# %%
import tensorflow as tf
# tf.enable_eager_execution()
# tf.executing_eagerly() # True

tf.config.run_functions_eagerly(True) # version 2

# %%
# %run ensemble.py

# %%
# %run test_retina_keras.py

# %%
# def argmax_func(x):
#     return np.argmax(x).astype(np.float32)

# def to_numpy(arg):
#   return np.asarray(arg).astype(np.float32)

# def shape_func(x):
#   y = tf.shape(x)[0]
#   return tf.cast(y, tf.float32)

# @tf.function
# def add_sample_weights(image, label):
#     y_classes = tf.numpy_function(argmax_func, [label], tf.float32)
#     pos = tf.math.reduce_sum(y_classes)
#     total = tf.numpy_function(shape_func, [label], tf.float32)
#     print(total)
#     neg = total - pos
#     w0 = (1 / neg) * (total / 2.0)
#     w1 = (1 / pos) * (total / 2.0)
#     weight_for_0 = tf.numpy_function(to_numpy, [w0], np.float32)
#     weight_for_1 = tf.numpy_function(to_numpy, [w1], np.float32)
#     class_weights = tf.convert_to_tensor([weight_for_0, weight_for_1])
#     # class_weights = class_weights/tf.reduce_sum(class_weights)

#     # Create an image of `sample_weights` by using the label at each pixel as an index into the `class weights` .
#     sample_weights = tf.gather(class_weights, indices=tf.cast(label, tf.int32))
#     print("output: ",  class_weights)
#     return image, label, class_weights
  

# image = np.random.uniform((100,27,27,3))
# label = np.random.randint((100,2))
# ds_train = add_sample_weights(image, label)
# images, labels, weights = ds_train
# print(weights.numpy())
# weights = {i : item for i, item in enumerate(weights.numpy())}
# print(weights)
